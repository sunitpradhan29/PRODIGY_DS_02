# %% [markdown]
# Task_2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Cleanning the data set

# %%
df1 = pd.read_csv(r"C:\Users\sunit\prodigy_tasks\titanic\test.csv", encoding='utf-8')
df1
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df2=pd.read_csv(r"C:\Users\sunit\prodigy_tasks\titanic\train.csv",encoding='utf-8')
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
concat_df = pd.concat([df1, df2], axis=0)
concat_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived
# ...

# %%
concat_df.describe()
# Out:
#        PassengerId       Pclass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean    655.000000     2.294882    29.881138     0.498854     0.385027
# std     378.020061     0.837836    14.413493     1.041658     0.865560
# min       1.000000     1.000000     0.170000     0.000000     0.000000
# 25%     328.000000     2.000000    21.000000     0.000000     0.000000
# 50%     655.000000     3.000000    28.000000     0.000000     0.000000
# 75%     982.000000     3.000000    39.000000     1.000000     0.000000
# max    1309.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare    Survived
# count  1308.000000  891.000000
# mean     33.295479    0.383838
# std      51.758668    0.486592
# min       0.000000    0.000000
# 25%       7.895800    0.000000
# 50%      14.454200    0.000000
# 75%      31.275000    1.000000
# max     512.329200    1.000000

# %%
concat_df.drop_duplicates(inplace=True)  
concat_df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 886          887       2                         Montvila, Rev. Juozas
# 887          888       1                  Graham, Miss. Margaret Edith
# 888          889       3      Johnston, Miss. Catherine Helen "Carrie"
# 889          890       1                         Behr, Mr. Karl Howell
# 890          891       3                           Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked  Survived
# ...

# %%
concat_df.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# Survived        418
# dtype: int64

# %%
concat_df['Age'].dtype
avg_age=concat_df['Age'].mean()
avg_age
# Out:
# 29.881137667304014

# %%
concat_df['Age'] = concat_df['Age'].fillna(avg_age)

# %%
concat_df['Fare']=concat_df['Fare'].fillna(concat_df['Fare'].mean())

# %%
concat_df.isnull().sum()
# Out:
# PassengerId       0
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              0
# Cabin          1014
# Embarked          2
# Survived        418
# dtype: int64

# %%
concat_df['Cabin'].dtype
# Out:
# dtype('O')

# %%
concat_df=concat_df.drop('Cabin', axis=1)

# %%
print(concat_df['Embarked'].dtype)
concat_df['Embarked']=concat_df['Embarked'].fillna(concat_df['Embarked'].mode()[0])
# Out:
# object

# %%
concat_df['Survived'].dtype
concat_df['Survived']=concat_df['Survived'].fillna(concat_df['Survived'].mean())

# %%
concat_df.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# Survived       0
# dtype: int64

# %%
concat_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Embarked  Survived
# 0  34.5      0      0   330911   7.8292        Q  0.383838
# 1  47.0      1      0   363272   7.0000        S  0.383838
# 2  62.0      0      0   240276   9.6875        Q  0.383838
# 3  27.0      0      0   315154   8.6625        S  0.383838
# 4  22.0      1      1  3101298  12.2875        S  0.383838

# %%
concat_df.tail()
# Out:
#      PassengerId  Pclass                                      Name     Sex  \
# 886          887       2                     Montvila, Rev. Juozas    male
# 887          888       1              Graham, Miss. Margaret Edith  female
# 888          889       3  Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890       1                     Behr, Mr. Karl Howell    male
# 890          891       3                       Dooley, Mr. Patrick    male
#
#            Age  SibSp  Parch      Ticket   Fare Embarked  Survived
# 886  27.000000      0      0      211536  13.00        S       0.0
# 887  19.000000      0      0      112053  30.00        S       1.0
# 888  29.881138      1      2  W./C. 6607  23.45        S       0.0
# 889  26.000000      0      0      111369  30.00        C       1.0
# 890  32.000000      0      0      370376   7.75        Q       0.0

# %%
numerical_columns = ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %% [markdown]
# age distribution

# %%
plt.figure(figsize=(6,3))
sns.histplot(concat_df['Age'],kde=True,bins=30)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(6, 3))
sns.countplot(data=concat_df, x="Sex", hue="Survived")
plt.title("Survival by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Survived", loc="upper right")
plt.show()

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(data=concat_df,x='Age',y='Fare',hue='Survived')
plt.title("Scatter Plot of Age vs Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="Survived")
plt.show()

# %% [markdown]
# correlation heat map between age and fare

# %%
correlation_matrix = concat_df[['Age', 'Fare']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='Blues', fmt='.2f')
plt.title('Correlation Heatmap between Age and Fare')
plt.show()

# %% [markdown]
# correlation heatmap

# %%
correlation_matrix = concat_df[numerical_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
def plot_survival_rate(df):
    fig,ax=plt.subplots()
    ax.pie(df['Survived'].value_counts(), labels=df['Survived'].value_counts().index, autopct='%1.1f%%')
    ax.set_title('Survival Rate')
    plt.show()
plot_survival_rate(concat_df)

# %% [markdown]
# 0.0>dead
# 0.38383>almost dead
# 1.0>survived
